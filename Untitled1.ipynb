# %% [markdown]
# <a href="https://colab.research.google.com/github/Gandham-Sony/AI-assignment-app/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install openpyxl

# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# os.chdir(r"C:\Users\gandh\Downloads")

# %% [markdown]
# To upload files from your local system to Colab, use the `files.upload()` function. A button will appear allowing you to select your file.

# %%
dfx = pd.read_excel('data_studentlist.xls')
dfx
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2294783698.py in <cell line: 0>()
# ----> 1 dfx = pd.read_excel('data_studentlist.xls')
#       2 dfx
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
val = pd.Series([-1.2, -1.5, -1.7], index=['two', 'four', 'five'])
val
# Out:
# two    -1.2
# four   -1.5
# five   -1.7
# dtype: float64

# %%
df = pd.DataFrame([[15,'male', 'A_middle_school'], [17,'female', 'B_middle_school']], index=['JunSeo', 'YeEun'], columns=['age','gender','school'])
df
# Out:
#         age  gender           school
# JunSeo   15    male  A_middle_school
# YeEun    17  female  B_middle_school

# %%
df.rename(columns={'age':'Age', 'gender':'Gender', 'school':'School'}, inplace=True)
df
# Out:
#         Age  Gender           School
# JunSeo   15    male  A_middle_school
# YeEun    17  female  B_middle_school

# %%
df.rename(index={'JunSeo':'Stu1', 'YeEun':'Stu2'}, inplace=True)
df
# Out:
#       Age  Gender           School
# Stu1   15    male  A_middle_school
# Stu2   17  female  B_middle_school

# %%
exam_date = {
    'Math' : [90, 80,70],
    'English' : [98, 89,95],
    'music' : [85,93,56],
    'science' : [100,84,92]
}
df  = pd.DataFrame(exam_date, index=['JunSeo', 'YeEun', 'Gildong'])
df
# Out:
#          Math  English  music  science
# JunSeo     90       98     85      100
# YeEun      80       89     93       84
# Gildong    70       95     56       92

# %%
df
# Out:
#          Math  English  music  science
# JunSeo     90       98     85      100
# YeEun      80       89     93       84
# Gildong    70       95     56       92

# %%
df_after_drop = df.drop(df.index[2])
df_after_drop
# Out:
#         Math  English  music  science
# JunSeo    90       98     85      100
# YeEun     80       89     93       84

# %%
df3 = df[:]
df3.drop(['JunSeo',], inplace=True)
df3
# Out:
# /tmp/ipython-input-3533237364.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop(['JunSeo',], inplace=True)
#          Math  English  music  science
# YeEun      80       89     93       84
# Gildong    70       95     56       92

# %%
df4 = df[:]
df4.drop(['Math'], axis=1, inplace=True)
df4
# Out:
# /tmp/ipython-input-3201710026.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4.drop(['Math'], axis=1, inplace=True)
#          English  music  science
# JunSeo        98     85      100
# YeEun         89     93       84
# Gildong       95     56       92

# %%
df5 = df[:]
df5.drop(['Math','English'], axis=1, inplace=True)
df5
# Out:
# /tmp/ipython-input-3306142522.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5.drop(['Math','English'], axis=1, inplace=True)
#          music  science
# JunSeo      85      100
# YeEun       93       84
# Gildong     56       92

# %%
# Select a row by its label using .loc
print("Row 'JunSeo' using .loc:")
print(df.loc['JunSeo'])

print("\n---")

# Select a row by its integer position using .iloc
print("First row (index 0) using .iloc:")
print(df.iloc[0])
# Out:
# Row 'JunSeo' using .loc:
# Math        90
# English     98
# music       85
# science    100
# Name: JunSeo, dtype: int64
#
# ---
# First row (index 0) using .iloc:
# Math        90
# English     98
# music       85
# science    100
# Name: JunSeo, dtype: int64

# %%
math1 = df['Math']
print(math1)
print(type(math1))
# Out:
# JunSeo     90
# YeEun      80
# Gildong    70
# Name: Math, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
music_eng = df[['music', 'English']]
print(music_eng)
print(type(music_eng))
# Out:
#          music  English
# JunSeo      85       98
# YeEun       93       89
# Gildong     56       95
# <class 'pandas.core.frame.DataFrame'>

# %%
exam_date = {
    'name' : ['JunSeo', 'YeEun', 'Gildong'],
    'Math' : [90, 80,70],
    'English' : [98, 89,95],
    'music' : [85,93,56],
    'science' : [100,84,92]
}
df = pd.DataFrame(exam_date)
df
# Out:
#       name  Math  English  music  science
# 0   JunSeo    90       98     85      100
# 1    YeEun    80       89     93       84
# 2  Gildong    70       95     56       92

# %%
df.set_index('name', inplace=True)
df
# Out:
#          Math  English  music  science
# name
# JunSeo     90       98     85      100
# YeEun      80       89     93       84
# Gildong    70       95     56       92

# %%
a = df.loc['JunSeo', 'English']
a
# Out:
# np.int64(98)

# %%
b = df.iloc[0,2]
b
# Out:
# np.int64(85)
